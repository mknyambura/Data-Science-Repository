# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:\\Users\\Nyambura\\Desktop\\Personal Data-Science-Projects\\FIFA Analysis with Data Science\\data.csv')

# %%
data.head()
# Out:
#    DOC_ID      ID               Name  Age  \
# 0       0  158023           L. Messi   31
# 1       1   20801  Cristiano Ronaldo   33
# 2       2  190871          Neymar Jr   26
# 3       3  193080             De Gea   27
# 4       4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.shape
# Out:
# (18207, 89)

# %%
#Let's eye Manchester City Footballers

def club(x):
    return data[data['Club'] == x][['Name', 'Jersey Number', 'Position', 'Nationality', 'Overall', 'Age', 'Wage', 'Value', 'Contract Valid Until']]

club('Manchester City')
# Out:
#                      Name  Jersey Number Position  Nationality  Overall  Age  \
# 4            K. De Bruyne            7.0      RCM      Belgium       91   27
# 13            David Silva           21.0      LCM        Spain       90   32
# 23              S. Agüero           10.0       ST    Argentina       89   30
# 55                L. Sané           19.0       LW      Germany       86   22
# 56         Bernardo Silva           11.0       RW     Portugal       86   23
# 57                Ederson           31.0       GK       Brazil       86   24
# 60            R. Sterling           10.0       RW      England       86   23
# 75            Fernandinho           25.0      CDM       Brazil       86   33
# 84              R. Mahrez           26.0       RW      Algeria       85   27
# 89            N. Otamendi           30.0       CB    Argentina       85   30
# 107            V. Kompany            4.0       CB      Belgium       85   32
# ...

# %%
club('Manchester United')
# Out:
#                   Name  Jersey Number Position  Nationality  Overall  Age  \
# 3               De Gea            1.0       GK        Spain       91   27
# 45            P. Pogba            6.0      RDM       France       87   25
# 47           R. Lukaku            9.0       ST      Belgium       87   25
# 93          A. Sánchez            7.0       RW        Chile       85   29
# 116         A. Martial           11.0       LW       France       84   22
# 132           N. Matić           31.0      CDM       Serbia       84   29
# 211          Juan Mata            8.0       RM        Spain       83   30
# 250               Fred           17.0       CM       Brazil       82   25
# 254         J. Lingard            7.0      CAM      England       82   25
# 319        M. Rashford           11.0       LW      England       81   20
# 327          E. Bailly            2.0       CB  Ivory Coast       81   24
# 374      Ander Herrera           21.0       CM        Spain       81   28
# ...

# %%
data.describe()
# Out:
#              DOC_ID             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
# Missing Values
data.isnull().any()
# Out:
# DOC_ID            False
# ID                False
# Name              False
# Age               False
# Photo             False
#                   ...
# GKHandling         True
# GKKicking          True
# GKPositioning      True
# GKReflexes         True
# Release Clause     True
# Length: 89, dtype: bool

# %%
data['ShortPassing'].isnull().any()
# Out:
# True

# %%
data['ShortPassing'].isnull().sum()
# Out:
# 48

# %%
data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace = True)

# %%
data['ShortPassing'].isnull().any()
# Out:
# False

# %%
data['Volleys'].isnull().any()
# Out:
# True

# %%
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace = True)
data['Curve'].fillna(data['Curve'].mean(), inplace = True)
data['FKAccuracy'].fillna(data['FKAccuracy'], inplace = True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace = True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace = True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace = True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace = True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace = True)
data['Weight'].fillna('200lbs', inplace = True)
data['Contract Valid Until'].fillna(2019, inplace = True)
data['Height'].fillna("5'11", inplace = True)
data['Loaned From'].fillna('None', inplace = True)
data['Joined'].fillna('Jul 1, 2018', inplace = True)
data['Jersey Number'].fillna(8, inplace = True)
data['Body Type'].fillna('Normal', inplace = True)
data['Position'].fillna('ST', inplace = True)
data['Club'].fillna('No Club', inplace = True)
data['Work Rate'].fillna('Medium/ Medium', inplace = True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace = True)
data['Weak Foot'].fillna(3, inplace = True)
data['Preferred Foot'].fillna('Right', inplace = True)
data['International Reputation'].fillna(1, inplace = True)
data['Wage'].fillna('€200K', inplace = True)
data.fillna(0, inplace = True)

# %%
data.isnull().any()
# Out:
# DOC_ID            False
# ID                False
# Name              False
# Age               False
# Photo             False
#                   ...
# GKHandling        False
# GKKicking         False
# GKPositioning     False
# GKReflexes        False
# Release Clause    False
# Length: 89, dtype: bool

# %%
data.isnull().sum()
# Out:
# DOC_ID            0
# ID                0
# Name              0
# Age               0
# Photo             0
#                  ..
# GKHandling        0
# GKKicking         0
# GKPositioning     0
# GKReflexes        0
# Release Clause    0
# Length: 89, dtype: int64

# %%
def defending(data):
    return int(round((data[['Marking', 'StandingTackle', 
                               'SlidingTackle']].mean()).mean()))

def general(data):
    return int(round((data[['HeadingAccuracy', 'Dribbling', 'Curve', 
                               'BallControl']].mean()).mean()))

def mental(data):
    return int(round((data[['Aggression', 'Interceptions', 'Positioning', 
                               'Vision','Composure']].mean()).mean()))

def passing(data):
    return int(round((data[['Crossing', 'ShortPassing', 
                               'LongPassing']].mean()).mean()))

def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed', 
                               'Agility','Reactions']].mean()).mean()))
def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina', 
                               'Strength']].mean()).mean()))

def rating(data):
    return int(round((data[['Potential', 'Overall']].mean()).mean()))

def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy', 
                               'ShotPower','LongShots', 'Penalties']].mean()).mean()))

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Renaming Columns
data.rename(columns={'Club Logo':'Club_Logo'}, inplace=True)

# %%
data.Club_Logo
# Out:
# 0          https://cdn.sofifa.org/teams/2/light/241.png
# 1           https://cdn.sofifa.org/teams/2/light/45.png
# 2           https://cdn.sofifa.org/teams/2/light/73.png
# 3           https://cdn.sofifa.org/teams/2/light/11.png
# 4           https://cdn.sofifa.org/teams/2/light/10.png
#                               ...
# 18202      https://cdn.sofifa.org/teams/2/light/121.png
# 18203      https://cdn.sofifa.org/teams/2/light/703.png
# 18204     https://cdn.sofifa.org/teams/2/light/1944.png
# 18205    https://cdn.sofifa.org/teams/2/light/15048.png
# 18206    https://cdn.sofifa.org/teams/2/light/15048.png
# Name: Club_Logo, Length: 18207, dtype: object

# %%
# adding these categories to the data

data['Defending'] = data.apply(defending, axis = 1)
data['General'] = data.apply(general, axis = 1)
data['Mental'] = data.apply(mental, axis = 1)
data['Passing'] = data.apply(passing, axis = 1)
data['Mobility'] = data.apply(mobility, axis = 1)
data['Power'] = data.apply(power, axis = 1)
data['Rating'] = data.apply(rating, axis = 1)
data['Shooting'] = data.apply(shooting, axis = 1)

# %%
players = data[['Name','Defending','General','Mental','Passing',
                'Mobility','Power','Rating','Shooting','Flag','Age',
                'Nationality', 'Photo', 'Club_Logo', 'Club']]

players.head()
# Out:
#                 Name  Defending  General  Mental  Passing  Mobility  Power  \
# 0           L. Messi         29       89      71       87        91     74
# 1  Cristiano Ronaldo         27       88      73       81        91     83
# 2          Neymar Jr         28       85      72       80        94     69
# 3             De Gea         16       26      43       39        66     54
# 4       K. De Bruyne         59       79      81       92        81     76
#
#    Rating  Shooting                                 Flag  Age Nationality  \
# 0      94        88  https://cdn.sofifa.org/flags/52.png   31   Argentina
# 1      94        88  https://cdn.sofifa.org/flags/38.png   33    Portugal
# 2      92        84  https://cdn.sofifa.org/flags/54.png   26      Brazil
# 3      92        21  https://cdn.sofifa.org/flags/45.png   27       Spain
# 4      92        85   https://cdn.sofifa.org/flags/7.png   27     Belgium
#
#                                             Photo  \
# ...

# %% [markdown]
# # Data visualisation

# %%
plt.figure(figsize = (10, 5))
sns.countplot(data['Preferred Foot'], palette = 'Wistia')
plt.title('Most Preferred Foot of the Players')
plt.show()

# %% [markdown]
# # Share of Intenrational Reputation

# %%
labels = ['1', '2', '3', '4', '5']
sizes = data['International Reputation'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0.1, 0.1, 0.2, 0.5, 0.9]

plt.figure(figsize = (9,9))
plt.pie(sizes, labels = labels, colors = colors, explode = explode)
plt.title('International Repuatation for the Football Players', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# # Positions acquired by players

# %%
plt.figure(figsize = (10, 8))
plt.style.use('fivethirtyeight')
ax = sns.countplot('Position', data = data, palette = 'magma')
ax.set_xlabel(xlabel = 'Positions', fontsize = 16)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 16)
ax.set_title(label = 'Positions and Players Comparisons', fontsize = 16)
plt.show()

# %%
type(data['Weight'])
# Out:
# pandas.core.series.Series

# %%
def extract_value_from(value):
    out = value.replace('lbs', '')
    return float(out)

# %%
data['Weight'] = data['Weight'].apply(lambda x : extract_value_from(x))

# %%
data['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
data['Wage']
# Out:
# 0        €565K
# 1        €405K
# 2        €290K
# 3        €260K
# 4        €355K
#          ...
# 18202      €1K
# 18203      €1K
# 18204      €1K
# 18205      €1K
# 18206      €1K
# Name: Wage, Length: 18207, dtype: object

# %%
def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1000
    return float(out)

# %%
data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
data['Wage'] = data['Wage'].apply(lambda x: extract_value_from(x))

data['Wage'].head()
# Out:
# 0    565000.0
# 1    405000.0
# 2    290000.0
# 3    260000.0
# 4    355000.0
# Name: Wage, dtype: float64

# %% [markdown]
# # Compare Players' Wages

# %%
plt.figure(figsize = (15, 5))
sns.distplot(data['Wage'], color = 'blue')
plt.xlabel('Wage Range', fontsize = 16)
plt.ylabel('Count of Players', fontsize = 16)
plt.title('Distribution of Wages of Players', fontsize = 22)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Number of Player Skill Moves

# %%
plt.figure(figsize = (10, 8))
ax = sns.countplot(x = 'Skill Moves', data = data)
ax.set_title(label = 'Number of Players on Basis of their Skill Moves', fontsize = 15)
ax.set_xlabel(xlabel = 'Number of Skill Moves', fontsize = 15)
ax.set_ylabel(ylabel = 'Player Count', fontsize = 15)
plt.show()

# %% [markdown]
# # Height of Players

# %%
plt.figure(figsize = (15, 10))
ax = sns.countplot(x = 'Height', data = data)
ax.set_title(label = "Pleyer's Heights", fontsize = 15)
ax.set_xlabel(xlabel = 'Height (Foot Per Inch)', fontsize = 15)
ax.set_ylabel(ylabel = 'Player Count', fontsize = 15)
plt.show()

# %% [markdown]
# # Weight of Players

# %%
plt.figure(figsize = (20,10))
sns.distplot(data['Weight'], color = 'cyan')
plt.title('FIFA 2019 Player Weights', fontsize = 15)
plt.xlabel('Heights associated with the Players', fontsize = 15)
plt.ylabel('Players', fontsize = 15)
plt.show()

# %% [markdown]
# # Work Rate of Players in FIFA 2019

# %%
plt.figure(figsize = (15, 10))

sns.countplot(x = 'Work Rate', data = data)
plt.title('Work Rates of the Players FIFA 2019', fontsize = 15)
plt.xlabel('Work Rates associated with the Players')
plt.ylabel('Count of Players', fontsize = 15)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Speciality Score of FIFA 2019 Players

# %%
data.columns
# Out:
# Index(['DOC_ID', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club_Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
plt.figure(figsize = (15, 10))
plt.style.use('tableau-colorblind10')
ax = sns.distplot(data['Special'], bins = 50, kde = False, color = 'blue')
ax.set_xlabel('Special Score Range', fontsize = 15)
ax.set_ylabel('Player Count', fontsize = 15)
ax.set_title('Histogran for Special Score of FIFA 2019 Players', fontsize = 15)
plt.show()

# %% [markdown]
# # Potential Scores of FIFA 2019 Players

# %%
plt.figure(figsize = (15, 10))
plt.style.use('seaborn-paper')
ax = sns.distplot(data['Potential'], bins = 50, kde = False, color = 'y')
ax.set_xlabel("Player's Potential Score Range", fontsize = 15)
ax.set_ylabel('Number of Players', fontsize = 15)
ax.set_title('Histogran for Potential Scores of FIFA 2019 Players', fontsize = 15)
plt.show()

# %% [markdown]
# # Nations Participating in FIFA 2019

# %%
plt.style.use('dark_background')
data['Nationality'].value_counts().head(100).plot.bar(color = 'orange', figsize = (20, 10))
plt.title('Nations Participating in FIFA 2019', fontsize = 20, fontweight = 20)
plt.xlabel('Country Names', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.show()

# %% [markdown]
# # Countries with most Players

# %%
data['Nationality'].value_counts().head(38)
# Out:
# England                1662
# Germany                1198
# Spain                  1072
# Argentina               937
# France                  914
# Brazil                  827
# Italy                   702
# Colombia                618
# Japan                   478
# Netherlands             453
# Sweden                  397
# China PR                392
# Chile                   391
# Republic of Ireland     368
# Mexico                  366
# United States           353
# Poland                  350
# Norway                  341
# Saudi Arabia            340
# Denmark                 336
# Korea Republic          335
# Portugal                322
# Turkey                  303
# Austria                 298
# Scotland                286
# Belgium                 260
# Australia               236
# Switzerland             220
# Uruguay                 149
# Senegal                 130
# Wales                   129
# Serbia                  126
# Croatia                 126
# ...

# %% [markdown]
# # Nation Player Weights

# %%
sample_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Colombia')
data_countries = data.loc[data['Nationality'].isin(sample_countries) & data['Weight']]

plt.style.use('bmh')
plt.figure(figsize = (20, 12))
ax = sns.violinplot(x = data_countries['Nationality'], y = data_countries['Weight'], palette = 'inferno')
ax.set_xlabel(xlabel = 'Countries', fontsize = 20)
ax.set_ylabel(ylabel = 'Weight in lbs', fontsize = 20)
ax.set_title(label = 'Distribution of Weight of Players', fontsize = 20)
plt.show()

# %% [markdown]
# # Popular clubs around the globe

# %%
data['Club'].value_counts().head(20)
# Out:
# No Club                    241
# Real Madrid                 33
# Fortuna Düsseldorf          33
# Newcastle United            33
# FC Barcelona                33
# AS Monaco                   33
# Wolverhampton Wanderers     33
# Frosinone                   33
# Liverpool                   33
# Arsenal                     33
# Burnley                     33
# Tottenham Hotspur           33
# Eintracht Frankfurt         33
# Atlético Madrid             33
# Borussia Dortmund           33
# Valencia CF                 33
# Southampton                 33
# Manchester United           33
# RC Celta                    33
# Rayo Vallecano              33
# Name: Club, dtype: int64

# %%
sample_clubs = ('Newcastle United', 'FC Barcelona', 'Southampton', 'Manchester United', 'Tottenham Hotspur', 'Arsenal', 'Chelsea', 'Liverpool', 'Manchester City', 'Real Madrid')
data_clubs = data.loc[data['Club'].isin(sample_clubs) & data['Overall']]

plt.style.use('bmh')
plt.figure(figsize = (20, 12))
ax = sns.boxplot(x = data_clubs['Club'], y = data_clubs['Overall'], palette = 'coolwarm')
ax.set_xlabel(xlabel = 'Popular clubs', fontsize = 20)
ax.set_ylabel(ylabel = 'Overall Score', fontsize = 20)
ax.set_title(label = 'Distribution of Overall Score of Players', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Distribution of Wages in some Popular clubs

# %%
sample_clubs = ('Southampton', 'Tottenham Hotspur', 'FC Barcelona', 'Chelsea', 'Real Madrid', 'Manchester City', 'Manchester United', 'Arsenal', 'Liverpool')
data_club = data.loc[data['Club'].isin(sample_clubs) & data['Wage']]

plt.style.use('bmh')
plt.figure(figsize = (20, 12))
ax = sns.boxplot(x = 'Club', y = 'Wage', data = data_club, palette = 'Reds')
ax.set_title(label = 'Distribution of Wages in Popular clubs', fontsize = 20)
ax.set_xlabel(xlabel = 'Name of Popular clubs', fontsize = 20)
ax.set_ylabel(ylabel = 'Wages', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Left- footed VS Right-footed Footballers

# %% [markdown]
# ### Ball Control VS Dribbling

# %%
plt.style.use('bmh')
sns.lmplot(x = 'BallControl', y = 'Dribbling', data = data, col = 'Preferred Foot')
plt.show()
