# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/kariu/OneDrive/Desktop/Data Science/Absenteeism_at_work/Absenteeism_at_work.csv')

# %%
data.head(10)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
# 5   3                  23                 7                6        1
# 6  10                  22                 7                6        1
# 7  20                  23                 7                6        1
# 8  14                  19                 7                2        1
# 9   1                  22                 7                2        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
# ...

# %%
print('Shape of dataset is:{}'.format(data.shape))
print('Type of features is:{}'.format(data.dtypes))
# Out:
# Shape of dataset is:(740, 21)
# Type of features is:ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# ...

# %%
data.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
data['Absenteeism time in hours'].mean()
# Out:
# 6.924324324324324

# %% [markdown]
# ### Here, we can see, that mean time of absence is 6.9 hours

# %%
sns.set_style('whitegrid')
sns.jointplot(x='Absenteeism time in hours',y='Seasons',data=data)

# %%
sns.jointplot(x='Age',y='Absenteeism time in hours',data=data)

# %%
sns.jointplot(x='Age',y='Absenteeism time in hours',data=data)

# %% [markdown]
# #### This graph shows, that hours of absence have some correlation with age of worker

# %%
plt.figure(figsize=(12,6))
sns.lmplot(x='Age', y='Absenteeism time in hours', data=data, hue='Day of the week', height=5, aspect=2)
plt.show()

# %% [markdown]
# #### Most of the time, absence is present in 6th day of the week, so, there are some correlation with not only age , but with day of the week as well

# %%
data[data['Day of the week']==6]['Absenteeism time in hours'].mean()
# Out:
# 5.125

# %% [markdown]
# #### Average time of absence on this day is little less, than across all days of the week

# %%
print(f"Day 6: {data[data['Day of the week']==6]['Absenteeism time in hours'].mean()} hours")
print(f"Day 5: {data[data['Day of the week']==5]['Absenteeism time in hours'].mean()} hours")
print(f"Day 4: {data[data['Day of the week']==4]['Absenteeism time in hours'].mean()} hours")
print(f"Day 3: {data[data['Day of the week']==3]['Absenteeism time in hours'].mean()} hours")
print(f"Day 2: {data[data['Day of the week']==2]['Absenteeism time in hours'].mean()} hours")
# Out:
# Day 6: 5.125 hours
# Day 5: 4.424 hours
# Day 4: 7.147435897435898 hours
# Day 3: 7.98051948051948 hours
# Day 2: 9.248447204968944 hours

# %%
data['Transportation expense'].mean()
# Out:
# 221.32972972972973

# %%
sns.jointplot(x='Transportation expense',
              y='Month of absence',
              data=data, 
              kind='hex', 
              color='red')

# %% [markdown]
# #### Also here, we can see that transportation expence is bigger in winter months than in other seasons

# %%
data['Son'].value_counts()
# Out:
# 0    298
# 1    229
# 2    156
# 4     42
# 3     15
# Name: Son, dtype: int64

# %% [markdown]
# ### This parameter shows number of children of each worker
# #### 298 have no children
# #### 229 have one child
# #### 156 have two children
# #### 15 have three children
# #### 42 have four children

# %%
plt.figure(figsize=(10,5))
data[data['Son']!=0]['Absenteeism time in hours'].plot.hist(bins=30)
plt.xlabel("'Son'/ Number of children")
plt.ylabel('Absenteeism time in hours')
plt.show()

# %% [markdown]
# ### In the group of people with children, absence in hours tends to be between 0 and 20, and very small amount was absence more than that

# %%
plt.figure(figsize=(10,6))
data[data['Son']==0]['Absenteeism time in hours'].plot.hist(bins=30)
plt.xlabel("'Son'/ Number of children")
plt.ylabel('Absenteeism time in hours')
plt.show()

# %% [markdown]
# ### The number of people without children showed more absenteeism than the people with children.

# %%
a = sns.FacetGrid(data=data,col='Son')
a.map(plt.hist,'Absenteeism time in hours')
plt.show()

# %% [markdown]
# ### Here all possible options for 'Son' column are shown in their correlation with absence time. We can see that, if you have 0 or 1 children, it is more likely to be absent at work. Probably, because if you have only one child and a mother presumably, noone can sit with child, apart from you and your spouse. Plus being a first time parent can be overwhelming given a parent is still learning the do and donts of parenting. But, if we look further, more children you have, less time you are absent. It means, that they can basically watch each other, and you dont need to stay home to take care of them and they have adopted the rules and day-to-day dos and donts of parenting

# %%
plt.figure(figsize=(14,6))
data[data['Son']==0]['Age'].plot.hist(bins=30)
plt.show()

# %%
plt.figure(figsize=(14,6))
data[data['Son']!=0]['Age'].plot.hist(bins=30)
plt.show()

# %% [markdown]
# #### Also here we can see that people without children mostly around 35 and 40. And obviously, some young people. And distrubition of age vs cnildren in the family.

# %%
plt.figure(figsize=(10,5))
sns.distplot(data['Reason for absence'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data[data['Reason for absence']==27].count()
# Out:
# ID                                 69
# Reason for absence                 69
# Month of absence                   69
# Day of the week                    69
# Seasons                            69
# Transportation expense             69
# Distance from Residence to Work    69
# Service time                       69
# Age                                69
# Work load Average/day              69
# Hit target                         69
# Disciplinary failure               69
# Education                          69
# Son                                69
# Social drinker                     69
# Social smoker                      69
# Pet                                69
# Weight                             69
# Height                             69
# Body mass index                    69
# Absenteeism time in hours          69
# dtype: int64

# %% [markdown]
# #### Reason 27 is according to Attributes is physiotherapy (27). So some amount of people are suffering from workload, possibly to make up time they spend at home with kids

# %%
data[data['Absenteeism time in hours']==0].count()
# Out:
# ID                                 44
# Reason for absence                 44
# Month of absence                   44
# Day of the week                    44
# Seasons                            44
# Transportation expense             44
# Distance from Residence to Work    44
# Service time                       44
# Age                                44
# Work load Average/day              44
# Hit target                         44
# Disciplinary failure               44
# Education                          44
# Son                                44
# Social drinker                     44
# Social smoker                      44
# Pet                                44
# Weight                             44
# Height                             44
# Body mass index                    44
# Absenteeism time in hours          44
# dtype: int64

# %%
print(f"Only {(44/740)*100}% of workers have never been absent from work")
# Out:
# Only 5.9459459459459465% of workers have never been absent from work

# %%
data.groupby('Reason for absence')['Absenteeism time in hours'].max()
# Out:
# Reason for absence
# 0       0
# 1      64
# 2      24
# 3       8
# 4       8
# 5       8
# 6     120
# 7      40
# 8       8
# 9     112
# 10     48
# 11    120
# 12    112
# 13    120
# 14     40
# 15      8
# 16      3
# 17      8
# 18     80
# 19    104
# 21      8
# 22     16
# 23     16
# 24      8
# 25      8
# 26     16
# 27      3
# 28     24
# Name: Absenteeism time in hours, dtype: int64

# %% [markdown]
# #### 6.VI Diseases of the nervous system 9.IX Diseases of the circulatory system
# #### 11.XI Diseases of the digestive system
# #### 12.XII Diseases of the skin and subcutaneous tissue
# #### 13.XIII Diseases of the musculoskeletal system and connective tissue
# #### 19 XIX Injury, poisoning and certain other consequences of external causes
#
# #### These are top reasons for absence
